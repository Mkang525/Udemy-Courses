# %%
import numpy as np
import pandas as pd
from numpy.random import randn
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
dataset = randn(100)

# %%
# To make a combined plot.  Seaborn has a built-in function for this
# by default distplot combines a kde plot with a histogram

sns.distplot(dataset, bins=25)

# %%
sns.distplot(dataset,bins=25,rug=True,hist=False)

# %%
# controlling specific plot within a set of plots by using a dictionary

sns.distplot(dataset, bins=25,
            kde_kws={'color':'indianred','label':'KDE PLOT'},
            hist_kws={'color':'blue','label':'HIST'})

# %%
#seaborn works very well with pandas

from pandas import Series

ser1 = Series(dataset,name='My_Data')
ser1
# Out:
# 0    -1.408830
# 1    -0.837761
# 2    -0.090656
# 3    -1.785792
# 4    -1.659317
#         ...
# 95   -0.177630
# 96    0.527570
# 97    0.306891
# 98    0.999817
# 99   -0.122157
# Name: My_Data, Length: 100, dtype: float64

# %%
sns.distplot(ser1,bins=25)
